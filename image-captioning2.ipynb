# %%
import pandas as pd

# %%
main = pd.read_csv("/content/latest_16batch.csv")
coco = pd.read_csv("/content/cocofixed.csv")
food = pd.read_csv("/content/foodfixed.csv")
travel = pd.read_csv("/content/travelfixed.csv")

# %%
main_old = main.copy()

# %%
coco['caption'][0]
# Out:
# ' The image features a street sign with a bicycle and a bus on it. The sign is yellow and placed on a pole. The street sign is located near a crosswalk, which is a designated area for pedestrians to cross the street safely. The scene also includes several cars parked or driving along the street. There are also a few people walking around the area, possibly pedestrians waiting to cross the street or passersby going about their daily activities.'

# %%
print(main["image_id"][main["image_id"] == coco['image_id'][0]])
coco['image_id'][0]
# Out:
# 90    test2017/000000117484
# Name: image_id, dtype: object
# 'test2017/000000117484'

# %%
main['caption'][main["image_id"] == coco['image_id'][0]].values[0]
# Out:
# '1. A baseball player in a white uniform is swinging a bat.\n2. A baseball player in a white uniform is swinging a bat.\n3. A baseball player in a white uniform is swinging a bat.\n4. A baseball player in a white uniform is swinging a bat.\n5. A baseball player in a white uniform is swinging a bat.\n6. A baseball player in a white uniform is swinging a bat.\n7. A baseball player in a white uniform is swinging a bat.\n8. A baseball player in a white uniform is swinging a bat.\n9. A baseball player in a white uniform is swinging a bat.\n10. A baseball player in a white uniform is swinging a bat.\n11. A baseball player in a white uniform is swinging a bat.\n12. A baseball player in a white uniform is swinging a bat.\n13.'

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48670 entries, 0 to 48669
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image_id  48670 non-null  object
#  1   caption   48670 non-null  object
# dtypes: object(2)
# memory usage: 760.6+ KB

# %%
main
# Out:
#                     image_id  \
# 0      test2017/000000480896
# 1      test2017/000000228698
# 2      test2017/000000227505
# 3      test2017/000000004236
# 4      test2017/000000310520
# ...                      ...
# 48665        test/food/07998
# 48666        test/food/07999
# 48667        test/food/08000
# 48668      test/travel/08001
# 48669      test/travel/08002
#
#                                                  caption
# 0      A plate of food is displayed on a dining table...
# 1      A woman in a blue shirt is playing a video gam...
# 2      A large white boat is floating on the water. T...
# 3      A herd of elephants is seen in a grassy area, ...
# 4      A cat is sitting inside a red suitcase, which ...
# ...                                                  ...
# 48665  A red train is traveling down the tracks, pass...
# 48666  A woman is standing on a skateboard in a skate...
# 48667  A glass of smoothie is placed on a table next ...
# ...

# %%
coco
# Out:
#                   image_id                                            caption
# 0    test2017/000000117484   The image features a street sign with a bicyc...
# 1    test2017/000000244479   The image depicts a large, well-equipped kitc...
# 2    test2017/000000262379   The image features a group of four people, tw...
# 3    test2017/000000524161   A group of people is gathered in a wooded are...
# 4    test2017/000000122738   The image features a large white polar bear w...
# ..                     ...                                                ...
# 285  test2017/000000120515   A red and white train is traveling down the t...
# 286  test2017/000000522098   The image features a vibrant display of fruit...
# 287  test2017/000000240375   A man is standing next to his bicycle, which ...
# 288  test2017/000000413708   A red double-decker bus is driving down the s...
# 289  test2017/000000446749   A person is cutting a birthday cake with a kn...
#
# [290 rows x 2 columns]

# %%
for i in range(coco['image_id'].shape[0]):
  main['caption'][main['image_id'] == coco['image_id'][i]] = coco['caption'][i]

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48670 entries, 0 to 48669
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image_id  48670 non-null  object
#  1   caption   48670 non-null  object
# dtypes: object(2)
# memory usage: 760.6+ KB

# %%
food
# Out:
#           image_id                                            caption
# 0  test/food/00138                 A bowl of soup with a spoon in it.
# 1  test/food/00565   A bowl of soup with a variety of vegetables, ...
# 2  test/food/00592   A plate of food with broccoli and other veget...
# 3  test/food/00969   A bowl of soup with a variety of vegetables, ...
# 4  test/food/01113     A plate of food with shrimp, peas, and greens.
# 5  test/food/01271         A pizza with shrimp and vegetables on top.
# 6  test/food/01804   A bowl of shrimp and greens, with a green sou...
# 7  test/food/07471      A close up of a dish with chicken and greens.
# 8  test/food/07510                 A tray of food with a spoon in it.
# 9  test/food/07769   A bowl of soup with various vegetables and meat.

# %%
for i in range(food['image_id'].shape[0]):
  main['caption'][main['image_id'] == food['image_id'][i]] = food['caption'][i]

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48670 entries, 0 to 48669
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image_id  48670 non-null  object
#  1   caption   48670 non-null  object
# dtypes: object(2)
# memory usage: 760.6+ KB

# %%
travel
# Out:
#              image_id                                            caption
# 0   test/travel/00964   A group of people, including a man in a blue ...
# 1   test/travel/01071   A large building with a gold roof and black w...
# 2   test/travel/01288   A large statue of a smiling Buddha is display...
# 3   test/travel/02021   A group of people are gathered around a statu...
# 4   test/travel/02122   A table is filled with food and wrapped gifts...
# 5   test/travel/02348   A large building with a gold roof and spires,...
# 6   test/travel/02350   A white building with a red roof and a green ...
# 7   test/travel/02644   A sign in a foreign language is posted on a c...
# 8   test/travel/02751   A wooden table with a sign on it. The sign is...
# 9   test/travel/02783   A wooden bench is situated next to a waterfal...
# 10  test/travel/02925   A man is kneeling on a green carpet in a mosq...
# 11  test/travel/02956   A man riding a bike down a narrow alleyway be...
# ...

# %%
for i in range(travel['image_id'].shape[0]):
  main['caption'][main['image_id'] == travel['image_id'][i]] = travel['caption'][i]

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48670 entries, 0 to 48669
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image_id  48670 non-null  object
#  1   caption   48670 non-null  object
# dtypes: object(2)
# memory usage: 760.6+ KB

# %%
coco['caption'][0]
# Out:
# ' The image features a street sign with a bicycle and a bus on it. The sign is yellow and placed on a pole. The street sign is located near a crosswalk, which is a designated area for pedestrians to cross the street safely. The scene also includes several cars parked or driving along the street. There are also a few people walking around the area, possibly pedestrians waiting to cross the street or passersby going about their daily activities.'

# %%
main['caption'][main["image_id"] == coco['image_id'][0]].values[0]
# Out:
# ' The image features a street sign with a bicycle and a bus on it. The sign is yellow and placed on a pole. The street sign is located near a crosswalk, which is a designated area for pedestrians to cross the street safely. The scene also includes several cars parked or driving along the street. There are also a few people walking around the area, possibly pedestrians waiting to cross the street or passersby going about their daily activities.'

# %%
main1 = main.iloc[:4867, :]
main2 = main.iloc[4867:9734, :]
main3 = main.iloc[9734:14601, :]
main4 = main.iloc[14601:19468, :]
main5 = main.iloc[19468:24335, :]
main6 = main.iloc[24335:29202, :]
main7 = main.iloc[29202:34069, :]
main8 = main.iloc[34069:38936, :]
main9 = main.iloc[38936:43803, :]
main10 = main.iloc[43803:48670, :]

# %%
main1.to_csv('latest_16batch1.csv')
main2.to_csv('latest_16batch2.csv')
main3.to_csv('latest_16batch3.csv')
main4.to_csv('latest_16batch4.csv')
main5.to_csv('latest_16batch5.csv')
main6.to_csv('latest_16batch6.csv')
main7.to_csv('latest_16batch7.csv')
main8.to_csv('latest_16batch8.csv')
main9.to_csv('latest_16batch9.csv')
main10.to_csv('latest_16batch10.csv')

# %%
for i in range(0,48670,4867):
  print(f'{i}:{i + 4867}')
# Out:
# 0:4867
# 4867:9734
# 9734:14601
# 14601:19468
# 19468:24335
# 24335:29202
# 29202:34069
# 34069:38936
# 38936:43803
# 43803:48670

# %%
4867 * 2
# Out:
# 9734

# %%
main.to_csv('/content/latest_16batch1.csv')
