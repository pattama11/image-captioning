# %%
#val(validation set) ใช้ตรวจสอบ
import pandas as pd
import json

# โหลดข้อมูล JSON
with open('/kaggle/input/ipu-24-test/ipu24_v0.4.1_coco.json', 'r') as f1:
    val = json.load(f1)

# ค้นหาความยาวของคอลัมน์ทั้งหมด
column_lengths = {key: len(value) for key, value in val.items()}

# หาความยาวของคอลัมน์ที่มากที่สุด
max_length = max(column_lengths.values())

# สร้าง DataFrame จาก JSON ด้วยการเพิ่มคอลัมน์ใหม่ที่มีความยาวเท่ากับคอลัมน์ที่มากที่สุด
df1 = pd.DataFrame({key: value + [None] * (max_length - len(value)) for key, value in val.items()})

# สลับแถวกับคอลัมน์ของ DataFrame
df1_swapped = df1.transpose()
# ตรวจสอบ DataFrame ที่ถูกสลับแถวกับคอลัมน์
df1_swapped.head()
# Out:
#                                                                         0  \
# train2017/000000373716  ผู้หญิงสวมเสื้อแขนยาวสีขาวและเด็กนั่งเล่นกับสุ...
# train2017/000000196888  สีน้ำตาลตัวเล็กกำลังกินอาหารอยู่บนจานกระดาษสีข...
# train2017/000000282238  ไปสัญญาณจราจร 3 อันติดอยู่บนเสาไฟสีดำแสดงสัญญา...
# train2017/000000267035  จานสีขาวจานนึงขบวนการนั้นมี โดนัทสอดไส้ทูน่าอย...
# train2017/000000214481  ห้องครัวห้องนึงที่มีตู้เก็บของเป็นสีน้ำตาลวางอ...
#
#                                                                         1  \
# train2017/000000373716  สาวคนนึงกำลังพาเด็กมานั่งเล่นอยู่ภายในสนามหญ้า...
# train2017/000000196888  นกน้อยตัวหนึ่งกำลังจิกกินเศษอาหารที่วางทิ้งไว้...
# train2017/000000282238   สัญญาณไฟจราจรที่ถูกติดตั้งอยู่กับเสาไฟอยู่ริมถนน
# train2017/000000267035  เบอร์เกอร์มีไส้เนื้อสัตว์และซอสสีขาวหั่นครึ่งช...
# train2017/000000214481  ห้องครัวที่มีข้าวของเครื่องใช้วางอยู่บนเคาน์เต...
#
# ...

# %%
#train(train set) ใช้เทรน
import pandas as pd
import json

# โหลดข้อมูล JSON
with open('/kaggle/input/thai-language-image-captioning/ipu24_v0.4.1_train.json', 'r') as f2:
    train = json.load(f2)

# ค้นหาความยาวของคอลัมน์ทั้งหมด
column_lengths = {key: len(value) for key, value in train.items()}

# หาความยาวของคอลัมน์ที่มากที่สุด
max_length = max(column_lengths.values())

# สร้าง DataFrame จาก JSON ด้วยการเพิ่มคอลัมน์ใหม่ที่มีความยาวเท่ากับคอลัมน์ที่มากที่สุด
df2 = pd.DataFrame({key: value + [None] * (max_length - len(value)) for key, value in train.items()})

# สลับแถวกับคอลัมน์ของ DataFrame
df2_swapped = df2.transpose()
# ตรวจสอบ DataFrame ที่ถูกสลับแถวกับคอลัมน์
df2_swapped.head()
# Out:
#                                                                     0  \
# train/travel/00000  รูปปั้นพญานาคตัวสีทองมีดอกบัวอยู่ด้านข้างอยู่ใ...
# train/travel/00001  โบราณสถานที่มีเจดีย์สีน้ำตาลดำมีต้นไม้หลายต้นด...
# train/travel/00002  พระพุทธรูปสีทององค์หนึ่งวางอยู่บนแท่นสีแดงปนน้...
# train/travel/00003  อาคารสีขาวที่มีหลังคาสีแดงมีรูปปั้นพญานาคติดอย...
# train/travel/00004  เจดีย์สีทองด้านล่างของเจดีย์เป็นรูปปั้นช้างหลา...
#
#                                                                     1  \
# train/travel/00000  รูปปั้นมังกรที่อยู่ภายในศาลเจ้าจีนและมีผ้าติดต...
# train/travel/00001  สร้างโบราณสถานขนาดใหญ่ที่อยู่ตรงพื้นที่เต็มไปด...
# train/travel/00002  พระพุทธรูปองค์หนึ่งที่มีสีทองวางตั้งอยู่บนแท่น...
# train/travel/00003  รูปปั้นพญานาคสีทอง 2 ตัวที่ติดตั้งอยู่ตรงบริเว...
# train/travel/00004  รูปปั้นช้างที่ตั้งอยู่บริเวณรอบๆเจดีย์สีทองขนา...
#
#                                                                     2     3  \
# ...

# %%
import pandas as pd
import json

# โหลดข้อมูล JSON
with open('/kaggle/input/thai-language-image-captioning/ipu24_v0.4.1_train.json', 'r') as f:
    data = json.load(f)

# ตรวจสอบความยาวของแต่ละคอลัมน์
column_lengths = {key: len(value) for key, value in data.items()}
print(column_lengths)

# เลือกข้อมูลเพียงบางส่วน (เช่น 10 รายการแรก) เพื่อตรวจสอบโครงสร้างข้อมูล
sample_data = {key: value[:10] for key, value in data.items()}
df = pd.DataFrame(sample_data)

# ตรวจสอบ DataFrame
print(df.head())
# Out:
# {'train/travel/00000': 3, 'train/travel/00001': 3, 'train/travel/00002': 3, 'train/travel/00003': 3, 'train/travel/00004': 3, 'train/travel/00005': 3, 'train/travel/00006': 3, 'train/travel/00007': 3, 'train/travel/00008': 3, 'train/travel/00009': 3, 'train/travel/00010': 4, 'train/travel/00011': 3, 'train/travel/00012': 3, 'train/travel/00013': 3, 'train/travel/00014': 3, 'train/travel/00015': 3, 'train/travel/00016': 3, 'train/travel/00017': 3, 'train/travel/00018': 3, 'train/travel/00019': 3, 'train/travel/00020': 3, 'train/travel/00021': 3, 'train/travel/00022': 3, 'train/travel/00023': 3, 'train/travel/00024': 4, 'train/travel/00025': 3, 'train/travel/00026': 3, 'train/travel/00027': 3, 'train/travel/00028': 3, 'train/travel/00029': 3, 'train/travel/00030': 3, 'train/travel/00031': 3, 'train/travel/00032': 3, 'train/travel/00033': 3, 'train/travel/00034': 3, 'train/travel/00035': 3, 'train/travel/00036': 3, 'train/travel/00037': 3, 'train/travel/00038': 3, 'train/travel/00039': 
# ...

# %%
# !pip install deep-translator
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
# อ่านข้อมูลจากไฟล์ sample_submission.csv
df = pd.read_csv('/kaggle/input/filecontinu2/outputS.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 import pandas as pd
#       2 # อ่านข้อมูลจากไฟล์ sample_submission.csv
# ----> 3 df = pd.read_csv('/kaggle/input/filecontinu2/outputS.csv')
#       4 df.head()
#
# ...

# %%
from transformers import GitVisionConfig, GitVisionModel

# Initializing a GitVisionConfig with microsoft/git-base style configuration
configuration = GitVisionConfig()

# Initializing a GitVisionModel (with random weights) from the microsoft/git-base style configuration
model = GitVisionModel(configuration)

# Accessing the model configuration
configuration = model.config

# %%
from transformers import GitConfig, GitModel

# Initializing a GIT microsoft/git-base style configuration
configuration = GitConfig()

# Initializing a model (with random weights) from the microsoft/git-base style configuration
model = GitModel(configuration)

# Accessing the model configuration
configuration = model.config

# %%
from transformers import AutoProcessor, AutoModelForCausalLM
import requests
from PIL import Image
import matplotlib.pyplot as plt
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # เลือกใช้ GPU ถ้ามีการใช้งานอยู่


processor = AutoProcessor.from_pretrained("microsoft/git-large-r-coco")
model = AutoModelForCausalLM.from_pretrained("microsoft/git-large-r-coco").to(device)

#processor = AutoProcessor.from_pretrained("microsoft/git-base-coco")
#model = AutoModelForCausalLM.from_pretrained("microsoft/git-base-coco").to(device)

# โหลดรูปภาพ
image_path = "/kaggle/input/thai-language-image-captioning/test/test/food/00003.jpg"
image = Image.open(image_path)

# แสดงรูปภาพ
plt.imshow(image)
plt.axis('off')
plt.show()

# การใช้ GPU ในการรันโมเดล
device = "cuda" if torch.cuda.is_available() else "cpu"

# ประมวลผลรูปภาพ
pixel_values = processor(images=image, return_tensors="pt").pixel_values.to(device)

# สร้างคำบรรยายภาพ
generated_ids = model.generate(pixel_values=pixel_values, max_length=50)
generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(generated_caption)
# Out:
# food at or somewhere near the hotel

# %%
from transformers import VisionEncoderDecoderModel, ViTImageProcessor, AutoTokenizer
import torch
from PIL import Image

model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
feature_extractor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
tokenizer = AutoTokenizer.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


max_length = 16
num_beams = 4
gen_kwargs = {"max_length": max_length, "num_beams": num_beams}
def predict_step(image_paths):
  images = []
  for image_path in image_paths:
    i_image = Image.open(image_path)
    if i_image.mode != "RGB":
      i_image = i_image.convert(mode="RGB")

    images.append(i_image)

  pixel_values = feature_extractor(images=images, return_tensors="pt").pixel_values
  pixel_values = pixel_values.to(device)

  output_ids = model.generate(pixel_values, **gen_kwargs)

  preds = tokenizer.batch_decode(output_ids, skip_special_tokens=True)
  preds = [pred.strip() for pred in preds]
  return preds


generated_caption = predict_step(['/kaggle/input/thai-language-image-captioning/test/test/food/00003.jpg']) # ['a woman in a hospital bed with a woman in a hospital bed']
generated_caption
# Out:
# ['a plate of food with vegetables and meat']

# %%
generated_caption
# Out:
# ['a plate of food with vegetables and meat']

# %%
from deep_translator import GoogleTranslator

# สร้างอ็อบเจกต์ Translator
translator = GoogleTranslator(source='english', target='thai')

# ข้อความที่ต้องการแปล
# english_text = "Hello, how are you?"

# แปลข้อความเป็นภาษาไทย
translated_text = translator.translate(generated_caption[0])

# แสดงผลลัพธ์
print(translated_text)
# Out:
# จานอาหารที่มีผักและเนื้อสัตว์

# %%
# แสดงรูปภาพ
plt.imshow(image)
plt.axis('off')  # ปิดแกน x และ y
plt.show()
print(generated_caption)
print(translated_text)
# Out:
# ['a plate of food with vegetables and meat']
# จานอาหารที่มีผักและเนื้อสัตว์

# %%
from tqdm import tqdm
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # เลือกใช้ GPU ถ้ามีการใช้งานอยู่

i = -1
initial = i  # กำหนดค่าเริ่มต้นของ tqdm

#for number in tqdm(df['image_id'], initial=initial):
for number in tqdm(df['image_id']):
    i += 1
    #tqdm.write(f"Processing image {i}...")  # เพิ่ม log การประมวลผลรูปภาพที่กำลังทำงาน
    #tqdm.write(f"Processing image {i}...")  # เพิ่ม log การประมวลผลรูปภาพที่กำลังทำงาน
    if i < 10000 :
        continue
    if i <= 40669 :
        image_path = f"/kaggle/input/coco-2017-dataset/coco2017/{df.loc[i, 'image_id']}.jpg"
    if i > 40669 :
        image_path = f"/kaggle/input/thai-language-image-captioning/test/{df.loc[i, 'image_id']}.jpg"    
    image = Image.open(image_path)
    pixel_values = processor(images=image, return_tensors="pt").pixel_values.to(device)
    generated_ids = model.generate(pixel_values=pixel_values, max_length=50)
    generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    translated_text = translator.translate(generated_caption)
    df.loc[i, 'caption'] = translated_text
    
    #i += 1
    
    output_path = "/kaggle/working/output.csv"
    df.to_csv(output_path, index=False)
    
    #if i == 30000 :
        #break
    if i == 48673 :
        break
        
#output_path = "/kaggle/working/output.csv"
#df.to_csv(output_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 10
#       7 initial = i  # กำหนดค่าเริ่มต้นของ tqdm
#       9 #for number in tqdm(df['image_id'], initial=initial):
# ---> 10 for number in tqdm(df['image_id']):
#      11     i += 1
#      12     #tqdm.write(f"Processing image {i}...")  # เพิ่ม log การประมวลผลรูปภาพที่กำลังทำงาน
#      13     #tqdm.write(f"Processing image {i}...")  # เพิ่ม log การประมวลผลรูปภาพที่กำลังทำงาน
#
# NameError: name 'df' is not defined

# %%
df[9999:10005]
# Out:
#                     image_id                                        caption
# 9999   test2017/000000279326                                            NaN
# 10000  test2017/000000021704                เด็กสาวถือไม้เบสบอลบนสนามเทนนิส
# 10001  test2017/000000277087        กลุ่มคนยืนอยู่บนเนินที่ปกคลุมไปด้วยหิมะ
# 10002  test2017/000000317717                ผู้หญิงและเด็กนั่งอยู่บนม้านั่ง
# 10003  test2017/000000078385  ออฟฟิศรกๆ ที่มีหนังสือพิมพ์กองหนึ่งอยู่บนโต๊ะ
# 10004  test2017/000000025384                   ถาดที่มีชามอาหารสองใบวางอยู่

# %%
output_path = "/kaggle/working/output.csv"
df.to_csv(output_path, index=False)
